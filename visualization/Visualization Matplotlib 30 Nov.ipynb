# %%
#installing matplotlib

#!pip install matplotlin

# %%
##import library 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %% [markdown]
# # matplotlib line plot

# %%
x=np.linspace(1,10,15)
y=[1,2,65,4,21,25,36,12,45,89,6,95,56,45,85]
plt.plot(x,y)
#plt.show()

# %%
#change the size of the graph
plt.rcParams['figure.figsize']=(10,5)

#dpi is pixel size
plt.rcParams['figure.dpi']=150

# %%
plt.plot(x,y,'r--')

# %%
a=np.random.randint(1,10,25)
plt.plot(a,'cyan',linewidth=5,linestyle='--')

# %%
x=np.array([1,2,3,4])
y=x*2
y
# Out:
# array([2, 4, 6, 8])

# %%
plt.plot(x,y,'r--')

# %%
x=np.array([1,2,3,4])
y=x*2

plt.plot(x,y,'r--')

x1=[2,4,6,8]
y1=[3,5,7,9]

plt.plot(x1,y1)

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('X vs Y line graph')
# Out:
# Text(0.5, 1.0, 'X vs Y line graph')

# %%
#grid used tabular graph
x1=[2,4,6,8]
y1=[3,5,7,9]

plt.plot(x1,y1)
plt.grid()

# %%
area = [1000,1520,2000,3000,5210]
price = [10,15,12,25,30]
plt.plot(area,price)
plt.grid()
plt.xlim(1000,6000)
plt.ylim(5,50)
plt.xlabel('Area of the house')
plt.ylabel('Price of the house')
# Out:
# Text(0, 0.5, 'Price of the house')

# %%
x = np.arange(1,20)
y1 =np.sqrt(x)
y2 =np.log(x)

plt.plot(x,y1,color='b',label='Square Root')
plt.plot(x,y2,color='g',label='Log')
plt.legend()

# %% [markdown]
# # Matplotlib Histogram

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv(r'C:\Users\asus\Downloads\Datasets-main\Automobile_data.csv')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df.shape[1]
# Out:
# 26

# %%
df.describe().T
# Out:
#                    count         mean         std     min     25%     50%  \
# symboling          205.0     0.834146    1.245307    -2.0     0.0     1.0
# wheel-base         205.0    98.756585    6.021776    86.6    94.5    97.0
# length             205.0   174.049268   12.337289   141.1   166.3   173.2
# width              205.0    65.907805    2.145204    60.3    64.1    65.5
# height             205.0    53.724878    2.443522    47.8    52.0    54.1
# curb-weight        205.0  2555.565854  520.680204  1488.0  2145.0  2414.0
# engine-size        205.0   126.907317   41.642693    61.0    97.0   120.0
# compression-ratio  205.0    10.142537    3.972040     7.0     8.6     9.0
# city-mpg           205.0    25.219512    6.542142    13.0    19.0    24.0
# highway-mpg        205.0    30.751220    6.886443    16.0    25.0    30.0
#
#                       75%     max
# symboling             2.0     3.0
# wheel-base          102.4   120.9
# length              183.1   208.1
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
plt.hist(df['width'])
plt.title('width frequency table')
plt.xlabel('Width')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
width_mean  = df['width'].mean()
width_median = df['width'].median()

df['width'].hist(bins=10)
plt.axvline(width_mean,color='y')
plt.axvline(width_median,color='r')


plt.ylabel('Frequency')
plt.xlabel('Width')
# Out:
# Text(0.5, 0, 'Width')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df['body-style'].hist(bins=5,grid=False,alpha=0.5,histtype='bar',ec='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # SEABORN

# %%
import seaborn as sns
sns.countplot(df['body-style'])
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='body-style', ylabel='count'>

# %%
df['body-style'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
df['make'].nunique()
# Out:
# 22

# %%
#set theme and style for graph

sns.set_theme(style='darkgrid',palette='rainbow')

# %%
sns.countplot(y='make',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='make'>

# %%
sns.countplot(data=df,x='body-style',hue="fuel-type")
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='count'>

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
#distributio plots

# %%
sns.histplot(df['curb-weight'])
# Out:
# <AxesSubplot:xlabel='curb-weight', ylabel='Count'>

# %%
sns.distplot(df['curb-weight'])
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='curb-weight', ylabel='Density'>

# %%
sns.kdeplot(df['curb-weight'])
# Out:
# <AxesSubplot:xlabel='curb-weight', ylabel='Density'>

# %% [markdown]
# # BoxPlot

# %%
#import necessary librarie

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\asus\Downloads\Datasets-main\cars.csv')

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.describe()
# Out:
#         symboling       width      height  engine-size    city-mpg  \
# count  205.000000  205.000000  205.000000   205.000000  205.000000
# mean     0.834146   65.907805   53.724878   126.907317   25.219512
# std      1.245307    2.145204    2.443522    41.642693    6.542142
# min     -2.000000   60.300000   47.800000    61.000000   13.000000
# 25%      0.000000   64.100000   52.000000    97.000000   19.000000
# 50%      1.000000   65.500000   54.100000   120.000000   24.000000
# 75%      2.000000   66.900000   55.500000   141.000000   30.000000
# max      3.000000   72.300000   59.800000   326.000000   49.000000
#
#        highway-mpg         price
# count   205.000000    205.000000
# mean     30.751220  13227.478049
# std       6.886443   7902.651615
# min      16.000000   5118.000000
# 25%      25.000000   7788.000000
# 50%      30.000000  10345.000000
# 75%      34.000000  16500.000000
# max      54.000000  45400.000000

# %%
df.describe(include='O')
# Out:
#        normalized-losses    make fuel-type body-style drive-wheels  \
# count                205     205       205        205          205
# unique                52      22         2          5            3
# top                    ?  toyota       gas      sedan          fwd
# freq                  41      32       185         96          120
#
#        engine-location engine-type horsepower
# count              205         205        205
# unique               2           7         60
# top              front         ohc         68
# freq               202         148         19

# %%
# Set the figure of the graph

# %%
plt.rcParams['figure.figsize']=(10,5)
plt.rcParams['figure.dpi']=250

# %%
#Selecting numerical coloums

# %%
num_cols=df.select_dtypes([int,float])

num_cols
# Out:
#      symboling  width  height  engine-size  city-mpg  highway-mpg  price
# 0            3   64.1    48.8          130        21           27  13495
# 1            3   64.1    48.8          130        21           27  16500
# 2            1   65.5    52.4          152        19           26  16500
# 3            2   66.2    54.3          109        24           30  13950
# 4            2   66.4    54.3          136        18           22  17450
# ..         ...    ...     ...          ...       ...          ...    ...
# 200         -1   68.9    55.5          141        23           28  16845
# 201         -1   68.8    55.5          141        19           25  19045
# 202         -1   68.9    55.5          173        18           23  21485
# 203         -1   68.9    55.5          145        26           27  22470
# 204         -1   68.9    55.5          141        19           25  22625
#
# [205 rows x 7 columns]

# %%
#matplotlib boxplot

# %%
plt.boxplot(num_cols)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c72667d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c70f5d880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20c726677f0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x20c70f5d130>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x20c7267a0d0>,
# ...
#  'means': []}

# %%
plt.boxplot(df['symboling'],notch=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c728ff610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c728ffbb0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x20c728ff250>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c72923190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c72923460>],
#  'means': []}

# %%
num_cols.drop(columns=['price','engine-size']).boxplot()
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(num_cols['city-mpg'])
plt.grid()

# %% [markdown]
# # seaborn boxplot

# %%
#set theme and style

sns.set_theme(style='darkgrid',palette='rainbow')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
sns.boxplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.boxplot(df['price'],df['make'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='make'>
